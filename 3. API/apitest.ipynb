# %%
url = "http://apis.data.go.kr/1360000/AsosHourlyInfoService/getWthrDataList?ServiceKey=f5e6f36a000142e7ad6c0f18249081ecb4e5123d7abf406a1e551d987068d16e&pageNo=1&numOfRows=100&dataType=JSON&dataCd=ASOS&dateCd=HR&startDt=20260721&startHh=09&endDt=20260721&endHh=16&stnIds=108"

# %%
import requests

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(data)
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'}, 'body': {'dataType': 'JSON', 'items': {'item': [{'tm': '2026-07-21 09:00', 'rnum': '1', 'stnId': '108', 'stnNm': '서울', 'ta': '25.6', 'taQcflg': '', 'rn': '0.0', 'rnQcflg': '', 'ws': '2.3', 'wsQcflg': '', 'wd': '160', 'wdQcflg': '', 'hm': '89', 'hmQcflg': '', 'pv': '29.1', 'td': '23.6', 'pa': '995.5', 'paQcflg': '', 'ps': '1005.2', 'psQcflg': '', 'ss': '0.0', 'ssQcflg': '', 'icsr': '0.13', 'dsnw': '', 'hr3Fhsc': '', 'dc10Tca': '10', 'dc10LmcsCa': '10', 'clfmAbbrCd': '', 'lcsCh': '6', 'vs': '2083', 'gndSttCd': '', 'dmstMtphNo': '01', 'ts': '24.5', 'tsQcflg': '', 'm005Te': '24.3', 'm01Te': '25.3', 'm02Te': '25.5', 'm03Te': '25.8'}, {'tm': '2026-07-21 10:00', 'rnum': '2', 'stnId': '108', 'stnNm': '서울', 'ta': '25.6', 'taQcflg': '', 'rn': '0.6', 'rnQcflg': '', 'ws': '1.5', 'wsQcflg': '', 'wd': '160', 'wdQcflg': '', 'hm': '93', 'hmQcflg': '', 'pv': '30.4', 'td': '24.3', 'pa': '995.3', 'paQcflg': '', 'ps': '1005.0',
# ...

# %%
json_data = data['response']['body']['items']['item']

json_data[0]
# Out:
# {'tm': '2026-07-21 09:00',
#  'rnum': '1',
#  'stnId': '108',
#  'stnNm': '서울',
#  'ta': '25.6',
#  'taQcflg': '',
#  'rn': '0.0',
#  'rnQcflg': '',
#  'ws': '2.3',
#  'wsQcflg': '',
#  'wd': '160',
#  'wdQcflg': '',
#  'hm': '89',
#  'hmQcflg': '',
#  'pv': '29.1',
#  'td': '23.6',
#  'pa': '995.5',
#  'paQcflg': '',
#  'ps': '1005.2',
#  'psQcflg': '',
#  'ss': '0.0',
#  'ssQcflg': '',
#  'icsr': '0.13',
#  'dsnw': '',
#  'hr3Fhsc': '',
#  'dc10Tca': '10',
#  'dc10LmcsCa': '10',
#  'clfmAbbrCd': '',
#  'lcsCh': '6',
#  'vs': '2083',
#  'gndSttCd': '',
#  'dmstMtphNo': '01',
#  'ts': '24.5',
#  'tsQcflg': '',
#  'm005Te': '24.3',
#  'm01Te': '25.3',
#  'm02Te': '25.5',
#  'm03Te': '25.8'}

# %%
json_data[0]['rn']
# Out:
# '0.0'

# %%
import pandas as pd

weather_df = pd.DataFrame(data['response']['body']['items']['item'])

weather_df
# Out:
#                  tm rnum stnId stnNm    ta taQcflg   rn rnQcflg   ws wsQcflg  \
# 0  2026-07-21 09:00    1   108    서울  25.6          0.0          2.3
# 1  2026-07-21 10:00    2   108    서울  25.6          0.6          1.5
# 2  2026-07-21 11:00    3   108    서울  25.5          0.2          2.9
# 3  2026-07-21 12:00    4   108    서울  24.8          3.1          6.3
# 4  2026-07-21 13:00    5   108    서울  24.3          5.4          2.6
# 5  2026-07-21 14:00    6   108    서울  24.7          4.9          2.4
# 6  2026-07-21 15:00    7   108    서울  25.1          0.1          2.6
# 7  2026-07-21 16:00    8   108    서울  25.3          0.2          2.7
#
#    ... lcsCh    vs gndSttCd dmstMtphNo    ts tsQcflg m005Te m01Te m02Te m03Te
# 0  ...     6  2083                  01  24.5           24.3  25.3  25.5  25.8
# 1  ...     4  1178                  01  24.5           24.4  25.4  25.5  25.7
# 2  ...     3  1620                  01  24.9           24.4  25.5  25.6  25.7
# ...
